# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt

from telegram.datasphere.Model import Model

# %%
img = cv2.imread('img.png')
print (img.shape)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(img)
plt.show()
img1 = np.moveaxis(img, (0, 1, 2), (1, 2, 0))

print(img1.shape)
# Out:
# (512, 512, 3)
# (3, 512, 512)

# %%
img1 = img1 / 256

# %%
model = Model("bt1soaafjmhtf1f2j6ko", "b1gbnhth47rchbtmstlr", "bt16jq41r6uelhtvm018")

# %%
img2 = model.process(np.array([img1]))
# Out:
# t1.9euelZqJi4zJmcjGj5SOk43IkY3Nke3rnpWanM_JjsbOkY-TyIqdjMudy4nl8_dOY3BE-e9RAGMp_t3z9w4SbkT571EAYyn-zef1656VmsaOm5bJkoyJj4mSlJaemZOV7_zN5_XrnpWanJzKnY2bi5qaxpqaks6Mj8rv_cXrnpWaxo6blsmSjImPiZKUlp6Zk5U.6EX84TrHLI_LykYoMwIzCqGfb8cOXU2iqu43U7yqQT94Fx7w6aVG45_ihJNqE87nc8ywEt1bu3EZubJZAx3EAg
# model_name: bt16jq41r6uelhtvm018,
#     model_ready: True,
# ...

# %%
img2 = img2[0]

# %%
img2 = np.moveaxis(img2, (0, 1, 2), (2, 0, 1))

# %%
img2.shape
# Out:
# (512, 512, 3)

# %%
plt.imshow(img2)
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.36499035..0.99291676].
