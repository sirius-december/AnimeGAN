# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt

from telegram.datasphere.Model import Model

# %%
img = cv2.imread('img.png')
print (img.shape)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(img)
plt.show()

print(img.shape)
# Out:
# (3502, 2876, 3)
# (3502, 2876, 3)

# %%
model = Model("bt1soaafjmhtf1f2j6ko", "b1gbnhth47rchbtmstlr", "bt16jq41r6uelhtvm018", 512)

# %%
result = model.process(img)
plt.imshow(result)
plt.show()
# Out:
# t1.9euelZqSk82XnsmMjpGVzorHjJyKmu3rnpWanM_JjsbOkY-TyIqdjMudy4nl9Pd9MHBE-e9_M0W03fT3PV9tRPnvfzNFtM3n9euelZrKjoyRmJqUj8yRxpiNiZ6Vyu_8zef1656Vmpycyp2Nm4uamsaampLOjI_K7_3F656VmsqOjJGYmpSPzJHGmI2JnpXK.laiJhK85GhcEzhNXzBz0m4WdbFu4k60pswUmP44zqmSmOLMZDyXT5F9w_Sj5_JsAfkCCEtrYFaWxLG7OZYhUAg

# %%
img.shape
# Out:
# (3502, 2876, 3)

# %%
img2 = img2[0]

# %%
img2 = np.moveaxis(img2, (0, 1, 2), (2, 0, 1))

# %%
img2.shape
# Out:
# (512, 512, 3)

# %%
plt.imshow((img2 + 1.0) / 2)
plt.show()
